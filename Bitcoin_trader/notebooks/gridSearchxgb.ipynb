# %%
import pandas as pd
import pandas_ta as ta
import datetime
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve, log_loss
import joblib

# %%
df = pd.read_csv('../data/btc_15m_data_2018_to_2025.csv')
df.drop(columns=['Close time', 'Quote asset volume', 'Number of trades',  'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore'], inplace=True)
df.head()
df.set_index("Open time", inplace=True)
df.index = pd.to_datetime(df.index)

# %%
df.ta.sma(length=10, append=True)  # Short-term SMA
df.ta.ema(length=10, append=True)  # Short-term EMA
df.ta.wma(length=10, append=True)  # Short-term WMA
df.ta.macd(fast=5, slow=8, append=True)  # Faster MACD signals
df.ta.rsi(length=7, append=True)  # Shorter RSI for quicker overbought/oversold signals
df.ta.bbands(length=10, append=True)  # Shorter Bollinger Bands for volatility
df.ta.adx(length=7, append=True)  # Shorter ADX for quicker trend strength analysis
df.ta.stoch(length=7, append=True)  # Shorter Stochastic Oscillator
df.ta.willr(length=7, append=True)  # Shorter Williams %R
df.ta.roc(length=5, append=True)  # Shorter ROC for quicker momentum analysis
df.ta.cci(length=10, append=True)  # Shorter CCI for quicker overbought/oversold signals
df.ta.atr(length=7, append=True)  # Shorter ATR for quicker volatility analysis

# Additional indicators
df.ta.tsi(length=10, append=True)       # Shorter True Strength Index
df.ta.ichimoku(append=True)             # Ichimoku Cloud (default settings)
df.ta.obv(append=True)                  # On-Balance Volume (no window size)
df.ta.vwap(append=True)                 # Volume Weighted Average Price (no window size)
df.ta.donchian(length=10, append=True)  # Shorter Donchian Channels
df.ta.ema(length=5, append=True)        # Very short-term EMA


# Drop rows with NaN values after adding indicators
# df.dropna(inplace=True)
df.drop(columns=['ISB_26'])
# Display the first few rows of the updated DataFrame
df.dropna(inplace=True)

# %%
def triple_barrier_labels(df, upper_pct=0.01, lower_pct=-0.01, max_hold=5):
    labels = []
    for i in range(len(df)):
        max_target = df['Close'].iloc[i] * (1 + upper_pct)
        min_target = df['Close'].iloc[i] * (1 + lower_pct)
        
        future_prices = df['Close'].iloc[i+1:i+max_hold+1]
        touch_upper = (future_prices > max_target).any()
        touch_lower = (future_prices < min_target).any()
        
        if touch_upper and not touch_lower:
            labels.append('Long')
        elif touch_lower and not touch_upper:
            labels.append('Short')
        else:
            labels.append('Neutral')
    return labels

df['Signal'] = triple_barrier_labels(df)
# Drop OHLC and Adj Close cause we need only indicators (If we need it cause for now we need Close price for backtesting our strategy)
df.drop(['Open', 'High', 'Low' ], axis=1, inplace=True)
df.dropna(inplace=True)

# %%
df['Signal'].value_counts()
# Out:
# Signal
# Neutral    211436
# Short       20943
# Long        20427
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)
df.to_csv('../data/btc_15m_data_2018_to_2025_with_indicatorsGrid.csv')
# Label encode the target column``
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df['Signal'])

# Prepare data
X = df.drop(['Signal'], axis=1)
y = y_encoded
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Split the data
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, shuffle=False)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
import joblib

# Define the parameter grid for XGBoost
param_grid = {
    'n_estimators': [200, 500, 1000],       # Number of trees
    'max_depth': [6, 8, 10, 12],              # Maximum depth of a tree
    'learning_rate': [0.01, 0.1, 0.2],   # Learning rate
    'subsample': [0.6, 0.8, 1.0],             # Subsample ratio of the training data
    'colsample_bytree': [0.8, 1.0],      # Subsample ratio of columns when constructing each tree
    'gamma': [0, 1, 5],                  # Minimum loss reduction required to make a split
}

# Initialize the XGBoost classifier
xgb_model = XGBClassifier( eval_metric='logloss')

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='accuracy',  # Metric to optimize
    cv=3,                # 3-fold cross-validation
    verbose=2,           # Print progress
    n_jobs=-1            # Use all available cores
)

# Train the model using GridSearchCV
print("Starting grid search...")
grid_search.fit(X_train, y_train)

# Classification report
y_pred = grid_search.predict(X_val)
print("Classification Report:")
print(classification_report(y_val, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_pred))


# Get the best parameters and the best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print("Best Parameters:", best_params)

# Evaluate the best model on the test set
accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", accuracy)

# Save the best model
joblib.dump(best_model, '../models/xgboost_model_gridsearch.joblib')
print("Best model saved as '../models/xgboost_model_gridsearch.joblib'")
# Out:
# Starting grid search...
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  31.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  32.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  32.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  32.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  32.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  32.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  32.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  32.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  36.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time=  58.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  37.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  38.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  38.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  38.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  38.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  39.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=16.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=16.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=16.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time=17.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time=17.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time=17.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time=18.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time=18.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 3.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 4.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 7.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 7.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1.0; total time= 6.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1.0; total time= 7.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.8; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.8; total time=10.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.8; total time=10.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1.0; total time=25.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1.0; total time=25.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1.0; total time=29.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1.0; total time=25.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=73.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=73.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=65.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=66.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=50.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=49.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1.0; total time=50.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1.0; total time=50.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=31.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=31.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=31.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=31.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=31.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=1.0; total time=31.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=31.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.6; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.6; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=1.0; total time=31.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.6; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.8; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.8; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=1.0; total time= 3.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=1.0; total time= 6.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=1.0; total time= 4.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=200, subsample=1.0; total time= 4.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.6; total time= 9.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.6; total time=10.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.6; total time=10.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.8; total time=11.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.8; total time=11.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=0.8; total time=11.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=1.0; total time=12.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=500, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.6; total time=17.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.6; total time=17.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.6; total time=  54.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.6; total time=16.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.6; total time=  54.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.6; total time=  55.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.8; total time=  53.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.8; total time=  53.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.8; total time=  51.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=1.0; total time=  46.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.8; total time=17.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.8; total time=17.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=1.0; total time=  44.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=1.0; total time=  43.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=0.8; total time=17.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=1.0; total time=16.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.6; total time= 4.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=1.0; total time=16.4min
# /opt/anaconda3/envs/Universal/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.6; total time= 4.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.8; total time= 3.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.6; total time= 4.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.8; total time= 3.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.8; total time= 3.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1.0; total time= 3.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1.0; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1.0; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=12, n_estimators=1000, subsample=1.0; total time=16.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.6; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.6; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.6; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=500, subsample=1.0; total time= 3.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8; total time= 6.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.6; total time= 6.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.6; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.6; total time= 7.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8; total time= 6.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8; total time= 6.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1.0; total time= 6.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1.0; total time= 6.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.6; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.6; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.6; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1.0; total time= 6.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.6; total time= 5.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.6; total time= 5.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.6; total time= 5.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.8; total time= 5.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=1.0; total time= 4.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.8; total time= 5.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.8; total time= 5.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=1.0; total time= 4.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=1.0; total time= 4.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.6; total time=40.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.6; total time=40.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.8; total time=39.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.8; total time=39.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.6; total time=39.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.8; total time=39.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=1.0; total time=37.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=1.0; total time=36.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=0.8; total time=16.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=1.0; total time=16.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=1.0; total time=16.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=200, subsample=1.0; total time=16.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=1.0; total time=18.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.6; total time=18.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.6; total time=18.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.6; total time=18.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.8; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.8; total time= 3.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time= 3.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time=18.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time=21.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time=21.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time=22.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time=21.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  25.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time=20.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time=21.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  14.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time=21.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  14.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  14.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  14.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  13.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  37.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  38.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  37.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time= 4.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  36.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  36.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  36.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  35.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  36.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  36.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  24.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  24.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time= 3.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  24.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  24.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  24.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  22.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  22.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  22.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time= 1.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time= 1.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time= 2.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time= 2.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  45.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  46.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  47.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  45.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  45.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  46.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  43.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  44.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  44.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time= 3.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time= 3.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time= 3.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time= 3.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time= 3.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time= 3.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time= 2.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 5.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 5.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 5.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 4.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 4.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time= 4.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  29.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 4.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  30.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=  34.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  34.3s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  34.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=  33.9s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  33.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  32.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=200, subsample=1.0; total time=  31.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time= 4.0min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.6; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time= 3.9min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.6; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  53.0s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  53.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.6; total time=  53.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.8; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  53.8s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time= 2.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  51.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.8; total time=  52.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=  53.5s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=  53.4s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=200, subsample=1.0; total time=  54.3s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.6; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=500, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.6; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1.0; total time= 3.5min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8; total time= 3.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1.0; total time= 3.6min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.6; total time= 1.5min
# ...
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time=  34.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.8; total time=  36.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=0.8; total time=  37.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time=  33.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=500, subsample=1.0; total time=  33.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time=  60.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time=  55.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  14.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  14.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time=  54.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  12.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=200, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  29.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  29.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  28.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.6; total time=  30.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=12, n_estimators=1000, subsample=1.0; total time=  51.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  24.9s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  28.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  27.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  25.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1.0; total time=  25.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time=  54.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time=  51.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time=  54.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.6; total time=  54.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time=  51.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=0.8; total time=  51.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time=  46.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time=  47.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  15.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.6; total time=  15.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  15.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=200, subsample=1.0; total time=  13.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=6, n_estimators=1000, subsample=1.0; total time=  47.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time=  30.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time=  30.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.6; total time=  30.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time=  25.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time=  28.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time=  28.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=0.8; total time=  28.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time=  25.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=500, subsample=1.0; total time=  25.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time=  54.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time=  54.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time=  50.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time=  51.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.8; total time=  51.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=0.6; total time=  54.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time=  45.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  14.9s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time=  46.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  15.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.6; total time=  15.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  15.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  14.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1.0; total time=  14.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=8, n_estimators=1000, subsample=1.0; total time=  48.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time=  32.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time=  32.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.6; total time=  33.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time=  28.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time=  28.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=1.0; total time=  28.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time=  53.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time=  54.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.8; total time=  55.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=0.6; total time=  56.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time=  48.4s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time=  48.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time=  15.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=0.8; total time=  14.8s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time=  14.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=10, n_estimators=1000, subsample=1.0; total time=  46.6s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time=  31.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time=  31.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.6; total time=  31.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time=  29.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time=  29.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time=  26.9s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time=  28.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=500, subsample=1.0; total time=  29.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time=  51.7s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time=  48.9s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.2, max_depth=12, n_estimators=1000, subsample=1.0; total time=  26.1s
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.30      0.42      2105
#            1       0.88      0.99      0.93     21061
#            2       0.72      0.31      0.43      2115
#
#     accuracy                           0.87     25281
#    macro avg       0.78      0.53      0.60     25281
# weighted avg       0.86      0.87      0.85     25281
#
# Confusion Matrix:
# [[  623  1397    85]
#  [  150 20746   165]
#  [   81  1378   656]]
# Best Parameters: {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 1000, 'subsample': 1.0}
# Test Accuracy: 0.8682014160832245
# Best model saved as '../models/xgboost_model_gridsearch.joblib'
